# %%
t=()

# %%
type(t)
# Out:
# tuple

# %%
t1=(1,2,3,4,5,67,8)

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 67, 8)

# %%
t2=(23.4,56.77,89.99,56.7)

# %%
t2
# Out:
# (23.4, 56.77, 89.99, 56.7)

# %%
t3=(12,"mayur",34.5,True)

# %%
t3
# Out:
# (12, 'mayur', 34.5, True)

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 67, 8)

# %%
t1[4]
# Out:
# 5

# %%
t1[::-2]
# Out:
# (8, 5, 3, 1)

# %%
t1[1:6:-2]
# Out:
# ()

# %%
t2[3:6:-3]
# Out:
# ()

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 67, 8)

# %%
t1[3]=1000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 t1[3]=1000
#
# TypeError: 'tuple' object does not support item assignment

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 67, 8)

# %%
l1=list(t1)

# %%
l1[3]=1000

# %%
tt=tuple(l1)

# %%
tt
# Out:
# (1, 2, 3, 1000, 5, 67, 8)

# %%
def convert_tuple_to_list(t):
    lst=[]
    for i in t:
        lst.append(i)
    return lst
t=(1, 2, 3, 1000, 5, 67, 8)
print(convert_tuple_to_list(t))
# Out:
# [1, 2, 3, 1000, 5, 67, 8]

# %%
t1
# Out:
# (1, 2, 3, 4, 5, 67, 8)

# %%
t1.append(34)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t1.append(34)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1=(2,3,4,5,6,7)
t2=(4,5,6,7,8,9)

# %%
t1=t1+t2

# %%
t1
# Out:
# (2, 3, 4, 5, 6, 7, 4, 5, 6, 7, 8, 9)

# %%
t2=t1+t2

# %%
t2
# Out:
# (2, 3, 4, 5, 6, 7, 4, 5, 6, 7, 8, 9, 4, 5, 6, 7, 8, 9)

# %%
t3=(2,3,4,5,6)
t4=(6,7,8,9,0)

# %%
t3+t4
# Out:
# (2, 3, 4, 5, 6, 6, 7, 8, 9, 0)

# %%
t3
# Out:
# (2, 3, 4, 5, 6)

# %%
t4
# Out:
# (6, 7, 8, 9, 0)

# %%
t1
# Out:
# (2, 3, 4, 5, 6, 7, 4, 5, 6, 7, 8, 9)

# %%
t1[4]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 t1[4]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
len(t1)
# Out:
# 12

# %%
def tuple_length(t):
    if t==():
        return 0
    else:
        return 1+tuple_length(t[1:])
t=(2, 3, 4, 5, 6, 7, 4, 5, 6, 7, 8, 9)
print(tuple_length(t))
# Out:
# 12

# %%
t2=(4,5,6,7,8,9,10)

# %%
any(t2)
# Out:
# True

# %%
t3=(0,0,0,0,0)

# %%
any(t3)
# Out:
# False

# %%
t4=(3,4,5,6,0,0,0)

# %%
any(t4)
# Out:
# True

# %%
def own_any(t):
    for i in t:
        if i!=0:
            return True
    return False
t=(0,0,0,0,1)
print(own_any(t))
# Out:
# True

# %%
def own_any_recursive(t):
    if t==():
        return False
    elif t[0]!=0:
        return True
    else:
        return own_any_recursive(t[1:])
    
    
t=(0,0,0,0,0) 
print(own_any_recursive(t))
# Out:
# False

# %%
t5=(1,2,3,4,5,6,7,8,9,0)

# %%
all(t5)
# Out:
# False

# %%
t6=(1,2,3,4,5,6,7,8)

# %%
all(t6)
# Out:
# True

# %%
def my_all(t):
    for i in t:
        if i==0:
            return False
        else:
            return True
t6=(1,2,3,4,0,6,7,8)
print( my_all(t6))
# Out:
# True

# %%
def my_all(t):
    for i in t:
        if i==0:
            return False
    return True
t=(1,2,3,4,5,6,7,8,1)
print(my_all(t))
# Out:
# True

# %%
def all_recursive(t):
    if t[0]==0:
        return False
    else:
        return True

# %%
t6=(3,4,5,6,7,8,9,0)

# %%
max(t6)
# Out:
# 9

# %%
min(t6)
# Out:
# 0

# %%
sum(t6)
# Out:
# 42

# %%
t7=(3,4,5,6,7,3,3,7,8,9,10)

# %%
t7.count(3)
# Out:
# 3

# %%
t7.index(10)
# Out:
# 10

# %%
t8=(2,-9,11,-34,56,27,89,99,-100,-123)

# %%
t9=sorted(t8)

# %%
t8
# Out:
# (2, -9, 11, -34, 56, 27, 89, 99, -100, -123)

# %%
t9
# Out:
# [-123, -100, -34, -9, 2, 11, 27, 56, 89, 99]

# %%
import numpy as np
def fun():
    d=np.random.randint(1,100,100)
    d2=np.random.randint(1,10,10)
    c=np.random.choice(d,size=len(d2))
    return c
fun()
# Out:
# array([98, 55, 15, 93, 94, 21, 73, 19, 55, 82])
