# %%
dict1={}

# %%
type(dict1)
# Out:
# dict

# %%
dict1={
    1:101,
    2:102,
    3:103
}

# %%
dict1
# Out:
# {1: 101, 2: 102, 3: 103}

# %%
dict2={
    1:101,
    2:102,
    3:103,
    3:200
}

# %%
dict2
# Out:
# {1: 101, 2: 102, 3: 200}

# %%
for i in dict2:
    print(i)
# Out:
# 1
# 2
# 3

# %%
dict3={
    10.1:1000,
    20.2:2000,
    30.3:3000
}

# %%
dict3
# Out:
# {10.1: 1000, 20.2: 2000, 30.3: 3000}

# %%
dict4={
    "abc":1000,
    "pqr":2000,
    "xyz":3000
}

# %%
dict4
# Out:
# {'abc': 1000, 'pqr': 2000, 'xyz': 3000}

# %%
dict5={
    2+4j:"mayur",
    5+7j:"abc"
}

# %%
dict5
# Out:
# {(2+4j): 'mayur', (5+7j): 'abc'}

# %%
dict6={
    True:100,
    False:400
}

# %%
dict6
# Out:
# {True: 100, False: 400}

# %%
dict7={
    [1,2,3,4,5]:1000,
    [7,8,9,10]:2000
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dict7={
#       2     [1,2,3,4,5]:1000,
#       3     [7,8,9,10]:2000
#       4 }
#
# TypeError: unhashable type: 'list'

# %%
dict8={
    (1,2,3):1000,
    (4,5,6):2000
}

# %%
dict8
# Out:
# {(1, 2, 3): 1000, (4, 5, 6): 2000}

# %%
dict9={
    {1,2,3}:345,
    {5,6,7}:678
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 dict9={
#       2     {1,2,3}:345,
#       3     {5,6,7}:678
#       4 }
#
# TypeError: unhashable type: 'set'

# %%
dict10={
    {1:100,2:200}:2000,
    {5:234,6:890}:3000
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 dict10={
#       2     {1:100,2:200}:2000,
#       3     {5:234,6:890}:3000
#       4 }
#
# TypeError: unhashable type: 'dict'

# %%
dict1
# Out:
# {1: 101, 2: 102, 3: 103}

# %%
dict1[1]
# Out:
# 101

# %%
dict1[2]
# Out:
# 102

# %%
dict1
# Out:
# {1: 101, 2: 102, 3: 103}

# %%
dict1[5]=5000

# %%
dict1
# Out:
# {1: 101, 2: 102, 3: 103, 5: 5000}

# %%
dict1[3]=300

# %%
dict1
# Out:
# {1: 101, 2: 102, 3: 300, 5: 5000}

# %%
dict1
# Out:
# {1: 101, 2: 102, 3: 300, 5: 5000}

# %%
len(dict1)
# Out:
# 4

# %%
def my_length(dict1):
    count=0
    for i in dict1:
        count+=1
    return count
dict1={1: 101, 2: 102, 3: 300, 5: 5000}
print(my_length(dict1))
# Out:
# 4

# %%
dict1[1:]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 dict1[1:]
#
# KeyError: slice(1, None, None)

# %%
dict1.pop(1)
# Out:
# 101

# %%
dict1
# Out:
# {2: 102, 3: 300, 5: 5000}

# %%
dict3
# Out:
# {10.1: 1000, 20.2: 2000, 30.3: 3000}

# %%
dict1.popitem()
# Out:
# (5, 5000)

# %%
dict1
# Out:
# {2: 102, 3: 300}

# %%
dict1.popitem()
# Out:
# (3, 300)

# %%
dict1
# Out:
# {2: 102}

# %%
def length_recursion(d,c=0):
    if d=={}:
        return c
    else:
        d.popitem()
        return length_recursion(d,c+1)
d={1:12,2:13,3:14,4:15}
print(length_recursion(d))
# Out:
# 4

# %%
def mylen(d,c=0):
    if d=={}:
        return 0
    else:
        x=d.popitem()
        return 1+mylen(d)
d={1:"Srk",2:"Rohit",3:"Krk"}        
mylen(d)
# Out:
# 3

# %%
d={1:"Srk",2:"Rohit",3:"Krk"}

# %%
d.popitem()
# Out:
# (3, 'Krk')

# %%
d
# Out:
# {1: 'Srk', 2: 'Rohit'}

# %%
del d[2]

# %%
d
# Out:
# {1: 'Srk'}

# %%
def my_popitem(dict1):

# %%
dict1
# Out:
# {2: 102}

# %%
dict2
# Out:
# {1: 101, 2: 102, 3: 200}

# %%
dict2[len(dict2)]
# Out:
# 200

# %%
def my_pop_item(dict1):
    value=0
    for i in dict1:
        value=i
    var=dict1[value]
    del dict1[value]
    return dict1,(value,var)
d={1: 101, 2: 102, 3: 200}
print(my_pop_item(d))
# Out:
# ({1: 101, 2: 102}, (3, 200))
