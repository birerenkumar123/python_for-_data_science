# %%
def my_function():
    pass

# %%
def myfunc():
    print("hello")

# %%
a$=56
# Out:
#   Cell In[4], line 1
#     a$=56
#      ^
# SyntaxError: invalid syntax

# %%
def paass():
print("hello")
# Out:
#   Cell In[5], line 2
#     print("hello")
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
age=int(input("enter age"))
if age>18:
    print("child")
else:
    print("adult")
# Out:
# enter age 90
# child

# %%
lst=[2,3,4,5,6,7]

# %%
lst[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 lst[8]
#
# IndexError: list index out of range

# %%
10/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
try:
    print(10/0)
except:
    print("handled")
# Out:
# handled

# %%
a=[1]*(100**10)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 a=[1]*(100**10)
#
# OverflowError: cannot fit 'int' into an index-sized integer

# %%
import math
print(math.factorial(100000))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 import math
# ----> 2 print(math.factorial(100000))
#
# ValueError: Exceeds the limit (4300 digits) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
f=open("kulkarni.txt","r")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 f=open("kulkarni.txt","r")
#
# File ~\anaconda3\anaconda4\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kulkarni.txt'

# %%
import ctypes
ctypes.string_at(0)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 2
#       1 import ctypes
# ----> 2 ctypes.string_at(0)
#
# File ~\anaconda3\anaconda4\Lib\ctypes\__init__.py:538, in string_at(ptr, size)
#     534 def string_at(ptr, size=-1):
#     535     """string_at(ptr[, size]) -> string
#     536
#     537     Return the byte string at void *ptr."""
# --> 538     return _string_at(ptr, size)
#
# OSError: exception: access violation reading 0x0000000000000000

# %%
def recursive_division(a,b):
    if a==0:
        return 0
    else:
        return 1+recursive_division((a-b),b)

# %%
recursive_division(4,2)
# Out:
# 2

# %%
recursive_division(4,0)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 recursive_division(4,0)
#
# Cell In[15], line 5, in recursive_division(a, b)
#       3     return 0
#       4 else:
# ----> 5     return 1+recursive_division((a-b),b)
#
# Cell In[15], line 5, in recursive_division(a, b)
#       3     return 0
#       4 else:
# ----> 5     return 1+recursive_division((a-b),b)
#
#     [... skipping similar frames: recursive_division at line 5 (2974 times)]
#
# Cell In[15], line 5, in recursive_division(a, b)
#       3     return 0
#       4 else:
# ----> 5     return 1+recursive_division((a-b),b)
#
# RecursionError: maximum recursion depth exceeded

# %%
try:
    a=int(input("enter any number"))
    b=int(input("enter second number"))
    print(a/b)
except:
    print("cannot divide by zero")
# Out:
# enter any number 4
# enter second number 0
# cannot divide by zero

# %%
f=open("kulkarni.txt","r")
print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 f=open("kulkarni.txt","r")
#       2 print(f.read())
#
# File ~\anaconda3\anaconda4\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kulkarni.txt'

# %%
try:
    f=open("kulkarni.txt","r")
    print(f.read())
except:
    print("file not present")
# Out:
# file not present

# %%
2+3
# Out:
# 5

# %%
2+6.7
# Out:
# 8.7

# %%
4+"mayur"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 4+"mayur"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
lst=[5,6,7,8,9]

# %%
lst[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 lst[9]
#
# IndexError: list index out of range

# %%
#string="aabaa,"
#handle attribte error
