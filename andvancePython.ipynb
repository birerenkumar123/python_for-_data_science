# %%
s={2,3,4,5,6,7}

# %%
for i in s:
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for s in range(0,len(s)):
    print(s[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 for s in range(0,len(s)):
# ----> 2     print(s[i])
#
# TypeError: 'int' object is not subscriptable

# %%
lst=[45,56,78,99]
for i,v in enumerate(lst,start=10):
    print(i,v)
# Out:
# 10 45
# 11 56
# 12 78
# 13 99

# %%
lst=[45,56,78,99]
for i,v in enumerate(lst,start=0):
    print(i,v)
# Out:
# 0 45
# 1 56
# 2 78
# 3 99

# %%
lst=["abc","qr","uvw"]
for i ,v in enumerate(lst,start="a"):
    print(i,v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 lst=["abc","qr","uvw"]
# ----> 2 for i ,v in enumerate(lst,start="a"):
#       3     print(i,v)
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
lst=[1,2,3,4,5,6,7,8]

# %%
def even(x):
    return x%2==0

# %%
list(filter(even,lst))
# Out:
# [2, 4, 6, 8]

# %%
lst=[-2,-89,67,-45,66]

# %%
def positive(x):
    return x>0

# %%
list(filter(positive,lst))
# Out:
# [67, 66]

# %%
a=45.6

# %%
isinstance(a,float)
# Out:
# True

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
isinstance(a,int)
# Out:
# False

# %%
class sample:
    print("hello")
# Out:
# hello

# %%
obj=sample()

# %%
isinstance(obj,sample)
# Out:
# True

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier()

# %%
isinstance(rf,RandomForestClassifier)
# Out:
# True

# %%
lst=[2,3,4,5,6]

# %%
def power(x):
    return x**2

# %%
map(power,lst)

# %%
list(map(power,lst))
# Out:
# [4, 9, 16, 25, 36]

# %%
def even_odd(x):
    if x%2==0:
        return True
    else:
        return False
lst=[1,2,3,4,5,6,7,8,10]
list(map(even_odd,lst))
# Out:
# [False, True, False, True, False, True, False, True, True]

# %%
columns=[2.7,4.5,4.4,2.9,3.7,3.3,8.9,8.7,11.2,34.23]

# %%
def normalized(x):
    var=max(columns)
    return x/var

# %%
list(map(normalized,columns))
# Out:
# [0.07887817703768625,
#  0.13146362839614376,
#  0.128542214431785,
#  0.08472100496640375,
#  0.10809231668127375,
#  0.09640666082383874,
#  0.26000584282792877,
#  0.2541630148992112,
#  0.32719836400818,
#  1.0]

# %%
lst=[1,2,3,4,5,6,7,8]

# %%
def product(x,y):
    return x*y

# %%
from functools import reduce

# %%
reduce(product,lst)
# Out:
# 40320

# %%
def average(a,b):
    var=(a+b)/2
    return var

# %%
reduce(average,lst)
# Out:
# 7.0078125

# %%
a=lambda x:x**2

# %%
a(5)
# Out:
# 25

# %%
lst=[2,4,6,8,10,9,17,19]

# %%
list(filter(lambda x:x%2==0,lst))
# Out:
# [2, 4, 6, 8, 10]

# %%
reduce(lambda x,y:x*y,lst)
# Out:
# 11162880

# %%
lst=["male","female","female","male","female"]

# %%
list(map(lambda gender:0 if gender=="male" else 1,lst))
# Out:
# [0, 1, 1, 0, 1]
